# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns 
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from xgboost import XGBRegressor
from sklearn.linear_model import Ridge
from sklearn.metrics import r2_score
import warnings
warnings.filterwarnings("ignore")

# %%
df1 = pd.read_csv('/kaggle/input/fbdddg/train.csv')
df2 = pd.read_csv('/kaggle/input/fbdddg/test.csv')
df3 = pd.read_csv('/kaggle/input/fbdddg/stores.csv')
df4 = pd.read_csv('/kaggle/input/fbdddg/transactions.csv')
df5 = pd.read_csv('/kaggle/input/fbdddg/holidays_events.csv')
df6 = pd.read_csv('/kaggle/input/fbdddg/oil.csv')

# %%
df1.head()
# Out:
#    id        date  store_nbr      family  sales  onpromotion
# 0   0  2013-01-01          1  AUTOMOTIVE    0.0            0
# 1   1  2013-01-01          1   BABY CARE    0.0            0
# 2   2  2013-01-01          1      BEAUTY    0.0            0
# 3   3  2013-01-01          1   BEVERAGES    0.0            0
# 4   4  2013-01-01          1       BOOKS    0.0            0

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000888 entries, 0 to 3000887
# Data columns (total 6 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   id           int64
#  1   date         object
#  2   store_nbr    int64
#  3   family       object
#  4   sales        float64
#  5   onpromotion  int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 137.4+ MB

# %%
df1.describe()
# Out:
#                  id     store_nbr         sales   onpromotion
# count  3.000888e+06  3.000888e+06  3.000888e+06  3.000888e+06
# mean   1.500444e+06  2.750000e+01  3.577757e+02  2.602770e+00
# std    8.662819e+05  1.558579e+01  1.101998e+03  1.221888e+01
# min    0.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00
# 25%    7.502218e+05  1.400000e+01  0.000000e+00  0.000000e+00
# 50%    1.500444e+06  2.750000e+01  1.100000e+01  0.000000e+00
# 75%    2.250665e+06  4.100000e+01  1.958473e+02  0.000000e+00
# max    3.000887e+06  5.400000e+01  1.247170e+05  7.410000e+02

# %%
df1.store_nbr.value_counts()
# Out:
# store_nbr
# 1     55572
# 46    55572
# 36    55572
# 37    55572
# 38    55572
# 39    55572
# 4     55572
# 40    55572
# 41    55572
# 42    55572
# 43    55572
# 44    55572
# 45    55572
# 47    55572
# 10    55572
# 48    55572
# 49    55572
# 5     55572
# 50    55572
# 51    55572
# 52    55572
# 53    55572
# 54    55572
# 6     55572
# 7     55572
# 8     55572
# 35    55572
# 34    55572
# 33    55572
# 32    55572
# 11    55572
# 12    55572
# 13    55572
# 14    55572
# 15    55572
# 16    55572
# 17    55572
# 18    55572
# 19    55572
# 2     55572
# 20    55572
# 21    55572
# 22    55572
# 23    55572
# 24    55572
# 25    55572
# 26    55572
# 27    55572
# 28    55572
# 29    55572
# 3     55572
# 30    55572
# 31    55572
# 9     55572
# Name: count, dtype: int64

# %%
sns.lineplot(x='store_nbr', y='sales', data=df1)
# Out:
# <Axes: xlabel='store_nbr', ylabel='sales'>

# %%
sns.lineplot(x="store_nbr", y="sales",
             hue="family",
             data=df1[10000:10300])
plt.show()

# %%
sns.lineplot(data=df6, palette='tab10', linewidth=2.5)
# Out:
# <Axes: >

# %%
sns.lineplot(data=df4, palette="tab10", linewidth=2.5)
# Out:
# <Axes: >

# %%
sns.distplot(df1['sales'])
plt.show()

# %%
df=pd.concat([df1,df2])
df.drop(columns='id',inplace=True)

# %%
df['date'] = pd.to_datetime(df['date'])
categorical_cols = ['store_nbr', 'family']

for col in categorical_cols:
    print(f"Unique values in {col}: {df[col].nunique()}")
# Out:
# Unique values in store_nbr: 54
# Unique values in family: 33

# %%
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
df['day'] = df['date'].dt.day
df['day_of_week'] = df['date'].dt.dayofweek
df['weekend'] = df['day_of_week'].isin([5, 6]).astype(int)

# %%
plt.figure(figsize=(8, 4))
plt.plot(df['date'], df['sales'], label='Sales')
plt.title('Sales Trends Over Time')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.legend()
plt.show()

# %%
plt.scatter(df['onpromotion'],df['sales'],alpha=0.5)
plt.show()

# %%
p=df.groupby('month')['sales'].mean()
p.plot(kind='bar')
plt.title('sales by month')
# Out:
# Text(0.5, 1.0, 'sales by month')

# %%
df.isnull().sum()
# Out:
# date               0
# store_nbr          0
# family             0
# sales          28512
# onpromotion        0
# year               0
# month              0
# day                0
# day_of_week        0
# weekend            0
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# date           0
# store_nbr      0
# family         0
# sales          0
# onpromotion    0
# year           0
# month          0
# day            0
# day_of_week    0
# weekend        0
# dtype: int64

# %%
df.drop('date', axis=1, inplace=True)

# %%
lab = LabelEncoder()

# %%
df.family = lab.fit_transform(df.family)
df
# Out:
#          store_nbr  family     sales  onpromotion  year  month  day  \
# 0                1       0     0.000            0  2013      1    1
# 1                1       1     0.000            0  2013      1    1
# 2                1       2     0.000            0  2013      1    1
# 3                1       3     0.000            0  2013      1    1
# 4                1       4     0.000            0  2013      1    1
# ...            ...     ...       ...          ...   ...    ...  ...
# 3000883          9      28   438.133            0  2017      8   15
# 3000884          9      29   154.553            1  2017      8   15
# 3000885          9      30  2419.729          148  2017      8   15
# 3000886          9      31   121.000            8  2017      8   15
# 3000887          9      32    16.000            0  2017      8   15
#
#          day_of_week  weekend
# 0                  1        0
# 1                  1        0
# 2                  1        0
# 3                  1        0
# 4                  1        0
# ...              ...      ...
# 3000883            1        0
# 3000884            1        0
# 3000885            1        0
# 3000886            1        0
# 3000887            1        0
#
# [3000888 rows x 9 columns]

# %%
sns.pairplot(df.iloc[:,1:5])

# %%
x = df.drop(['sales'], axis=1)
y = df['sales']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size = 0.25, random_state=20)

# %%
def kfolds(model, model_name):
    model = cross_val_score(model, x,y, cv=10)
    model_score = np.average(model)
    print(f"{model_name} score on cross validation: {model_score * 100}%")
def model_train(model,model_name):
    model.fit(X_train,Y_train)
    model_train_score = model.score(X_train, Y_train)
    model_test_score = model.score(X_test, Y_test)
    print(f"{model_name} model score on Train= {model_train_score *100}%\n{model_name}model score on Test= {model_test_score*100}%")

# %%
model = LinearRegression()
model_train(model, 'LinearRegression')
kfolds(model, 'LinearRegression')
# Out:
# LinearRegression model score on Train= 19.899753916719565%
# LinearRegressionmodel score on Test= 19.645436921646166%
# LinearRegression score on cross validation: 13.985475369707547%

# %%
model_XG = XGBRegressor()
model_train(model_XG, 'XGBRegressor')
kfolds(model_XG, 'XGBRegressor')
# Out:
# XGBRegressor model score on Train= 90.67972247453005%
# XGBRegressormodel score on Test= 89.60867244753898%
# XGBRegressor score on cross validation: 84.28264668269773%

# %%
model_RFR = DecisionTreeRegressor()
model_train(model_RFR,'DecisionTreeRegressor')
kfolds(model_RFR,'DecisionTreeRegressor')

# %%
mode_ploy = Ridge()
model_train(mode_ploy,'PolynomialFeatures')
kfolds(mode_ploy,'PolynomialFeatures')

# %%
pred_xgb = model_XG.predict(X_test)

# %%
pred_xgb

# %%
from sklearn.metrics import mean_squared_error

# %%
as = df2['id']

# %%
mse_xgb = mean_squared_error(Y_test, pred_xgb)
xgb_rmse = np.sqrt(mse_xgb)
print("rmse_xgb:", xgb_rmse)

submission = pd.DataFrame({'sales': pred_xgb})
print(submission)
submission.to_csv('submission1s.csv', index=False)

# %%
dfz=pd.concat([df1,df2])
dfz

# %%
submission
